# %%
import pandas as pd

# %%
df = pd.read_excel('sales.xlsx')
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[142], line 1
# ----> 1 df = pd.read_excel('sales.xlsx')
#       2 df
#
# File c:\Users\siswa\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\excel\_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
#     497         storage_options=storage_options,
#     498         engine=engine,
#     499         engine_kwargs=engine_kwargs,
#     500     )
#     501 elif engine and engine != io.engine:
# ...

# %%
from pyspark.sql import SparkSession

# %%
#importing pandas as pd 
import pandas as pd 
  
# Read and store content 
# of an excel file  
read_file = pd.read_excel ("sales.xlsx") 
  
# Write the dataframe object 
# into csv file 
read_file.to_csv ("sales.csv",  
                  index = None, 
                  header=True) 
    
# read csv file and convert  
# into a dataframe object 
df = pd.DataFrame(pd.read_csv("sales.csv")) 
  
# show the dataframe 
df
# Out:
#       Row ID        Order ID           Order Date            Ship Date  \
# 0          1  CA-2016-152156  2016-08-11 00:00:00  2016-11-11 00:00:00
# 1          2  CA-2016-152156  2016-08-11 00:00:00  2016-11-11 00:00:00
# 2          3  CA-2016-138688  2016-12-06 00:00:00            6/16/2016
# 3          4  US-2015-108966  2015-11-10 00:00:00           10/18/2015
# 4          5  US-2015-108966  2015-11-10 00:00:00           10/18/2015
# ...      ...             ...                  ...                  ...
# 9989    9990  CA-2014-110422            1/21/2014            1/23/2014
# 9990    9991  CA-2017-121258            2/26/2017  2017-03-03 00:00:00
# 9991    9992  CA-2017-121258            2/26/2017  2017-03-03 00:00:00
# 9992    9993  CA-2017-121258            2/26/2017  2017-03-03 00:00:00
# 9993    9994  CA-2017-119914  2017-04-05 00:00:00  2017-09-05 00:00:00
#
#            Ship Mode Customer ID        Country             City       State  \
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv('./data/amazon_sales_report.csv', index_col=0)
df
# Out:
# C:\Users\siswa\AppData\Local\Temp\ipykernel_11304\672968665.py:1: DtypeWarning: Columns (23) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('./data/amazon_sales_report.csv', index_col=0)
#                    Order ID       Date                        Status  \
# index
# 0       405-8078784-5731545  4/30/2022                     Cancelled
# 1       171-9198151-1101146  4/30/2022  Shipped - Delivered to Buyer
# 2       404-0687676-7273146  4/30/2022                       Shipped
# 3       403-9615377-8133951  4/30/2022                     Cancelled
# 4       407-1069790-7240320  4/30/2022                       Shipped
# ...                     ...        ...                           ...
# 128970  406-6001380-7673107  5/31/2022                       Shipped
# 128971  402-9551604-7544318  5/31/2022                       Shipped
# 128972  407-9547469-3152358  5/31/2022                       Shipped
# ...

# %%
df.columns
# Out:
# Index(['index', 'Order ID', 'Date', 'Status', 'Fulfilment', 'Sales Channel ',
#        'ship-service-level', 'Style', 'SKU', 'Category', 'Size', 'ASIN',
#        'Courier Status', 'Qty', 'currency', ' Amount ', 'ship-city',
#        'ship-state', 'ship-postal-code', 'ship-country', 'promotion-ids',
#        'B2B', 'fulfilled-by', 'Unnamed: 22'],
#       dtype='object')

# %%
df[df.duplicated(subset=['Order ID', 'SKU'], keep=False)]
# Out:
#                   Order ID       Date     Status Fulfilment Sales Channel   \
# index
# 30660  406-0372545-6086735  4/12/2022  Cancelled     Amazon      Amazon.in
# 30661  406-0372545-6086735  4/12/2022  Cancelled     Amazon      Amazon.in
# 41291  408-0373839-4433120   4/5/2022  Cancelled     Amazon      Amazon.in
# 41292  408-0373839-4433120   4/5/2022  Cancelled     Amazon      Amazon.in
# 52330  407-8364731-6449117  5/29/2022    Shipped     Amazon      Amazon.in
# 52333  407-8364731-6449117  5/29/2022    Shipped     Amazon      Amazon.in
# 79844  171-9628368-5329958   5/7/2022  Cancelled     Amazon      Amazon.in
# 79845  171-9628368-5329958   5/7/2022  Cancelled     Amazon      Amazon.in
# 85790  171-3249942-2207542   5/3/2022    Shipped     Amazon      Amazon.in
# 85791  171-3249942-2207542   5/3/2022    Shipped     Amazon      Amazon.in
# 86418  405-8669298-3850736   5/3/2022    Shipped     Amazon      Amazon.in
# ...

# %%
df_drop= df.drop_duplicates()
df_drop.shape
# Out:
# (128969, 23)

# %%
duplicate = df_drop[df_drop.duplicated(subset=['Order ID', 'SKU'],keep=False)]
duplicate.to_csv('./duplicate_order_sku_2.csv')
duplicate
# Out:
#                   Order ID       Date   Status Fulfilment Sales Channel   \
# index
# 52330  407-8364731-6449117  5/29/2022  Shipped     Amazon      Amazon.in
# 52333  407-8364731-6449117  5/29/2022  Shipped     Amazon      Amazon.in
#
#       ship-service-level    Style           SKU Category Size  ... currency  \
# index                                                          ...
# 52330          Expedited  JNE3769  JNE3769-KR-L    kurta    L  ...      NaN
# 52333          Expedited  JNE3769  JNE3769-KR-L    kurta    L  ...      INR
#
#         Amount   ship-city  ship-state ship-postal-code ship-country  \
# index
# 52330       NaN      Theni  TAMIL NADU         625579.0           IN
# 52333   487.00       Theni  TAMIL NADU         625579.0           IN
#
#                                       promotion-ids    B2B fulfilled-by  \
# index
# 52330  IN Core Free Shipping 2015/04/08 23-48-5-108  False          NaN
# ...

# %%
dim_product = df[["SKU", "Style", "Category", "Size", "ASIN"]]
dim_product
# Out:
#                     SKU    Style       Category Size        ASIN
# 0        SET389-KR-NP-S   SET389            Set    S  B09KXVBD7Z
# 1       JNE3781-KR-XXXL  JNE3781          kurta  3XL  B09K3WFS32
# 2         JNE3371-KR-XL  JNE3371          kurta   XL  B07WV4JV4D
# 3            J0341-DR-L    J0341  Western Dress    L  B099NRCT7B
# 4       JNE3671-TU-XXXL  JNE3671            Top  3XL  B098714BZP
# ...                 ...      ...            ...  ...         ...
# 128970    JNE3697-KR-XL  JNE3697          kurta   XL  B098112V2V
# 128971   SET401-KR-NP-M   SET401            Set    M  B09VC6KHX8
# 128972     J0157-DR-XXL    J0157  Western Dress  XXL  B0982YZ51B
# 128973     J0012-SKD-XS    J0012            Set   XS  B0894Y2NJQ
# 128974      J0003-SET-S    J0003            Set    S  B0894X27FC
#
# [128975 rows x 5 columns]

# %%
df.shape
# Out:
# (128975, 24)

# %%
dim_product[dim_product.duplicated(subset=['SKU', 'ASIN'])]
# Out:
#                    SKU    Style       Category Size        ASIN
# 57        JNE3405-KR-L  JNE3405          kurta    L  B081WSCKPQ
# 95        JNE3405-KR-L  JNE3405          kurta    L  B081WSCKPQ
# 99      JNE3405-KR-XXL  JNE3405          kurta  XXL  B081WSL2JS
# 101     SET347-KR-NP-S   SET347            Set    S  B09RKDJ9SQ
# 104     SET268-KR-NP-L   SET268            Set    L  B08XQ8MCKP
# ...                ...      ...            ...  ...         ...
# 128970   JNE3697-KR-XL  JNE3697          kurta   XL  B098112V2V
# 128971  SET401-KR-NP-M   SET401            Set    M  B09VC6KHX8
# 128972    J0157-DR-XXL    J0157  Western Dress  XXL  B0982YZ51B
# 128973    J0012-SKD-XS    J0012            Set   XS  B0894Y2NJQ
# 128974     J0003-SET-S    J0003            Set    S  B0894X27FC
#
# [121775 rows x 5 columns]

# %%
clean_prod = dim_product.drop_duplicates(subset=["SKU"])
clean_prod
# Out:
#                     SKU    Style       Category Size        ASIN
# 0        SET389-KR-NP-S   SET389            Set    S  B09KXVBD7Z
# 1       JNE3781-KR-XXXL  JNE3781          kurta  3XL  B09K3WFS32
# 2         JNE3371-KR-XL  JNE3371          kurta   XL  B07WV4JV4D
# 3            J0341-DR-L    J0341  Western Dress    L  B099NRCT7B
# 4       JNE3671-TU-XXXL  JNE3671            Top  3XL  B098714BZP
# ...                 ...      ...            ...  ...         ...
# 127616      J0319-KR-XL    J0319          kurta   XL  B08PV3R8YL
# 128095    JNE3398-KR-XL  JNE3398          kurta   XL  B082W81KNG
# 128529     JNE3370-KR-S  JNE3370          kurta    S  B081X6MVKK
# 128750   JNE3678-TU-XXL  JNE3678            Top  XXL  B0943HSR64
# 128794   SET045-KR-NP-M   SET045            Set    M  B07N81TFNY
#
# [7195 rows x 5 columns]

# %%
clean_prod[clean_prod.duplicated(subset=['ASIN'], keep=False)]
# Out:
#                        SKU    Style Category Size        ASIN
# 442       SET186-KR-DH-K-M   SET186      Set    M  B08B4TP9NR
# 450        JNE3440-KR-N-XL  JNE3440    kurta   XL  B081WPK66G
# 1443      JNE3313-KR-A-XXL  JNE3313    kurta  XXL  B07SMNGTKQ
# 4000          J0184-KR-A-S    J0184    kurta    S  B08V151HB2
# 4120        SET182-KR-DH-M   SET182      Set    M  B085NYG5CR
# 5848        SET186-KR-DH-M   SET186      Set    M  B08B4TP9NR
# 8823       JNE3313-KR-A-XS  JNE3313    kurta   XS  B07SHC649M
# 10953  SET014-KR-PP-A-XXXL   SET014      Set  3XL  B07K5BD23T
# 14057       SET014-KR-PP-L   SET014      Set    L  B07K5CC1S2
# 14407    JNE3313-KR-A-XXXL  JNE3313    kurta  3XL  B07SHCJLTR
# 17894    SET014-KR-PP-XXXL   SET014      Set  3XL  B07K5BD23T
# 20813           J0184-KR-S    J0184    kurta    S  B08V151HB2
# 23193     SET014-KR-PP-A-L   SET014      Set    L  B07K5CC1S2
# 35701      AN208-MUSTARD-M    AN208   Bottom    M  B091GNW3B1
# ...

# %%
df.columns
# Out:
# Index(['index', 'Order ID', 'Date', 'Status', 'Fulfilment', 'Sales Channel ',
#        'ship-service-level', 'Style', 'SKU', 'Category', 'Size', 'ASIN',
#        'Courier Status', 'Qty', 'currency', ' Amount ', 'ship-city',
#        'ship-state', 'ship-postal-code', 'ship-country', 'promotion-ids',
#        'B2B', 'fulfilled-by', 'Unnamed: 22'],
#       dtype='object')

# %%
dim_shipping = df[['Order ID', 'Fulfilment', 'Sales Channel ', 'ship-service-level', 'Courier Status']]
dim_shipping
# Out:
#                    Order ID Fulfilment Sales Channel  ship-service-level  \
# 0       405-8078784-5731545   Merchant      Amazon.in           Standard
# 1       171-9198151-1101146   Merchant      Amazon.in           Standard
# 2       404-0687676-7273146     Amazon      Amazon.in          Expedited
# 3       403-9615377-8133951   Merchant      Amazon.in           Standard
# 4       407-1069790-7240320     Amazon      Amazon.in          Expedited
# ...                     ...        ...            ...                ...
# 128970  406-6001380-7673107     Amazon      Amazon.in          Expedited
# 128971  402-9551604-7544318     Amazon      Amazon.in          Expedited
# 128972  407-9547469-3152358     Amazon      Amazon.in          Expedited
# 128973  402-6184140-0545956     Amazon      Amazon.in          Expedited
# 128974  408-7436540-8728312     Amazon      Amazon.in          Expedited
#
#        Courier Status
# 0                 NaN
# 1             Shipped
# ...

# %%
unshipped =  dim_shipping[dim_shipping['Courier Status'] == 'Unshipped']
unshipped = unshipped.drop_duplicates()
unshipped[unshipped.duplicated(subset=['Order ID'], keep=False)]
# Out:
#                    Order ID Fulfilment Sales Channel  ship-service-level  \
# 116     403-0104882-7373900     Amazon      Amazon.in          Expedited
# 117     403-0104882-7373900     Amazon      Amazon.in          Expedited
# 118     403-0104882-7373900     Amazon      Amazon.in          Expedited
# 1601    407-3147250-8940369     Amazon      Amazon.in          Expedited
# 1602    407-3147250-8940369     Amazon      Amazon.in          Expedited
# ...                     ...        ...            ...                ...
# 127884  405-3240881-5372353     Amazon      Amazon.in          Expedited
# 127933  171-9501006-4943519     Amazon      Amazon.in          Expedited
# 127934  171-9501006-4943519     Amazon      Amazon.in          Expedited
# 128787  403-4459458-8180313     Amazon      Amazon.in          Expedited
# 128788  403-4459458-8180313     Amazon      Amazon.in          Expedited
#
#        Courier Status
# 116         Unshipped
# 117         Unshipped
# ...

# %%
clean = dim_shipping.drop_duplicates(subset=['Order ID'], keep=)
clean[clean.duplicated(subset=['Order ID'], keep=False)]
# Out:
#                    Order ID Fulfilment Sales Channel  ship-service-level  \
# 1615    405-7790745-1369118     Amazon      Amazon.in          Expedited
# 1616    405-7790745-1369118     Amazon      Amazon.in          Expedited
# 1988    171-9673855-2321133     Amazon      Amazon.in          Expedited
# 1989    171-9673855-2321133     Amazon      Amazon.in          Expedited
# 2424    404-7478762-7926753     Amazon      Amazon.in          Expedited
# ...                     ...        ...            ...                ...
# 122220  402-6648472-4569935     Amazon      Amazon.in          Expedited
# 123005  407-3267554-0397119     Amazon      Amazon.in          Expedited
# 123006  407-3267554-0397119     Amazon      Amazon.in          Expedited
# 128085  406-6890147-5272318     Amazon      Amazon.in          Expedited
# 128086  406-6890147-5272318     Amazon      Amazon.in          Expedited
#
#        Courier Status
# 1615        Cancelled
# 1616          Shipped
# ...

# %%
clean['Courier Status'].unique()
# Out:
# array([nan, 'Shipped', 'Cancelled', 'Unshipped'], dtype=object)

# %%
date_dim
# Out:
#              Date  Year  Month  Day
# 0      2022-04-30  2022      4   30
# 1481   2022-04-29  2022      4   29
# 2947   2022-04-28  2022      4   28
# 4363   2022-04-27  2022      4   27
# 5822   2022-04-26  2022      4   26
# ...           ...   ...    ...  ...
# 121697 2022-06-05  2022      6    5
# 123283 2022-06-04  2022      6    4
# 124720 2022-06-03  2022      6    3
# 125948 2022-06-02  2022      6    2
# 127360 2022-06-01  2022      6    1
#
# [91 rows x 4 columns]

# %%
# 6. Fact Table
fact_sales = df[['Order ID', 'Date', 'SKU', 'Qty', ' Amount ', 'B2B', 'fulfilled-by']].copy()
fact_sales.rename(columns={' Amount ': 'Amount'}, inplace=True)  # Rename to fix spacing issues

fact_sales
# Out:
#                    Order ID       Date              SKU  Qty      Amount  \
# 0       405-8078784-5731545 2022-04-30   SET389-KR-NP-S    0     647.62
# 1       171-9198151-1101146 2022-04-30  JNE3781-KR-XXXL    1     406.00
# 2       404-0687676-7273146 2022-04-30    JNE3371-KR-XL    1     329.00
# 3       403-9615377-8133951 2022-04-30       J0341-DR-L    0     753.33
# 4       407-1069790-7240320 2022-04-30  JNE3671-TU-XXXL    1     574.00
# ...                     ...        ...              ...  ...         ...
# 128970  406-6001380-7673107 2022-05-31    JNE3697-KR-XL    1     517.00
# 128971  402-9551604-7544318 2022-05-31   SET401-KR-NP-M    1     999.00
# 128972  407-9547469-3152358 2022-05-31     J0157-DR-XXL    1     690.00
# 128973  402-6184140-0545956 2022-05-31     J0012-SKD-XS    1   1,199.00
# 128974  408-7436540-8728312 2022-05-31      J0003-SET-S    1     696.00
#
#           B2B fulfilled-by
# 0       False    Easy Ship
# 1       False    Easy Ship
# ...
